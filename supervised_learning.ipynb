# %% [markdown]
# # Предисловие
#
# Привет! Меня зовут Артур. <br>
# В рамках этого проекта я стажер небольшого отдела цифровых технологий в кампании интернет-магазина «В один клик».
#
#
# # Проект: Обучение с учителем: качество модели
#
# # Описание проекта
#
# Интернет-магазин «В один клик» продает разные товары:
# для детей, для дома, мелкую бытовую технику, косметику и даже продукты.
# Отчет магазина за прошлый период показал, что активность покупателей начала снижаться.
# Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории.
# Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому ее руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования.
# Нашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# # Описание данных
#
# Данные для работы находятся в следующих таблицах:
#
# **market_file.csv**
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это дает покупатель.
# - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев.
# Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# **market_money.csv**
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - `Выручка` — сумма выручки за период.
#
# **market_time.csv**
# Таблица с данными о времени (в минутах), которое покупатель провел на сайте в течение периода.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксировано общее время.
# - `минут` — значение времени, проведенного на сайте, в минутах.
#
# **money.csv**
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Прибыль` — значение прибыли.

# %% [markdown]
# # ТЗ заказчика (инструкция по выполнению проекта)
#
# Решать задачу вам нужно в два этапа:
#
# 1. Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность.
# Используйте:
# - данные моделирования,
# - данные о прибыли покупателей
# - и исходные данные (если понадобятся).
# (По желанию мы можете проанализировать больше одного сегмента).
#
# Ниже несколько примеров сегментов, но мы также можете выделить свой:
#
# - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.
#
# Продумывать подход к решению этой задачи вам не придется — руководитель отдела его уже сформировал:
#
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей.
#     В компании принято выделять два уровня активности:
#   - «снизилась», если клиент стал покупать меньше товаров,
#   - и «прежний уровень».
#
#
# 2. Нужно собрать данные по клиентам по следующим группам:
#   - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#   - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#   - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#   - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# Представим группы признаков (вместе с целевым) в виде диаграммы — такую визуализацию еще называют диаграммой Исикавы.
#
# ![image.png](attachment:image.png)
#
# На диаграмме входные признаки объединены в четыре группы: коммуникация с клиентом, продуктовое поведение, поведение на сайте и финансовое поведение.
#
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
#
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.
#
# Обратите внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.

# %%
# Установка и обновление библиотек
# !pip install -q --upgrade phik shap scikit-learn matplotlib

# %%
# Импорт библиотек и оформления ячеек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from phik.report import plot_correlation_matrix

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

import shap

# Оформление
from IPython.display import display, HTML

display(HTML("<style>.container {width:100% !important;} </style>")) # подгоняем размер тетрадки под ширину экрана
display(HTML("<style>:root { --jp-notebook-max-width: 100% !important; }</style>")) # иногда не работает та, что выше
pd.options.display.max_columns=None
pd.set_option('display.width', 1000) # для вывода всех колонок в ширину
pd.options.display.float_format = '{:.2f}'.format # удобнее смотреть на конечное кол-во цифр в выводе

# Чтобы пофиксить предупреждения
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# <style>.container {width:100% !important;} </style>
# <style>:root { --jp-notebook-max-width: 100% !important; }</style>

# %%
# Устанавливаем константы
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# ## Шаг 1. Загрузка данных
# 1.1 Загрузим данные:
# - `market_file.csv`,
# - `market_money.csv`,
# - `market_time.csv`,
# - `money.csv`
#
# 1.2 Проверим, что данные в таблицах соответствуют описанию.

# %%
# Загрузим данные в датафреймы
market_file = pd.read_csv(r"C:\GitProjects\Git-project-for-Yandex.Practicum\market_file.csv")
market_money = pd.read_csv(r"C:\GitProjects\Git-project-for-Yandex.Practicum\market_money.csv")
market_time = pd.read_csv(r"C:\GitProjects\Git-project-for-Yandex.Practicum\market_time.csv")
money = pd.read_csv(r"C:\GitProjects\Git-project-for-Yandex.Practicum\money.csv", sep=';', decimal=',')

# Создадим список датафреймов
df_dict = {'market_file': market_file,
           'market_money': market_money, 
           'market_time': market_time, 
           'money': money}

# Проверим данные
for df_name, df in df_dict.items():
    print('-' * 100, df_name)
    print('-' * 80, 'df.info()')
    df.info()
    print()
    
    if len(df.select_dtypes(include='number').columns) > 0:
        print('-' * 80, 'df.describe(include="number")')
        display(df.describe(include='number'))

    if len(df.select_dtypes(exclude='number').columns) > 0:
        print('-' * 80, 'df.describe(exclude="number")')
        display(df.describe(exclude='number'))

        print('-' * 80, 'col.unique()')
        for col_name, col in df.select_dtypes(exclude='number').items():
            print(f'{col_name}:', end='\n')
            for value in sorted(col.unique()):
                print(' ' * 4, value, end='\n')
            print()

    print('-' * 80, 'df.sample(5)')  
    display(df.sample(5))
    
    del df_name, df  # удаляем временные переменные, потому что они продолжают работать вне цикла
# Out:
# ---------------------------------------------------------------------------------------------------- market_file
# -------------------------------------------------------------------------------- df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
# ...

# %% [markdown]
# ### Промежуточный вывод: Загрузка данных
# Данные корректно загружены в датафреймы.
# Обнаружили следующие особенности:
# - в названиях колонок содержатся пробелы, в следующем шаге заменим их на нижнее подчеркивание
# (Н.: столбец `Тип сервиса` в датафрейме `market_file`)
# - некоторое столбцы в несоответствующем формате (Н.: столбец `Прибыль` в датафрейме `money`)
# - орфографические ошибки внутри колонок (Н.: `предыдцщий_месяц` вместо `предыдущий_месяц`)

# %% [markdown]
# ## Шаг 2. Предобработка данных
# Проведем предобработку данных (названия столбцов оставим кириллическими):
# - Привести подписи столбцов к одному формату
#     - т.к. большая часть столбцов начинается с заглавной буквы, то заменить те, что с маленькой, на заглавные.
#     - пробелы заменить на ниж. подчеркивание
# - Исправить орфографические ошибки
# - Изменить тип данных там, где это нужно
# - Проверить данные на пропуски и дубли
# - Столбец с ID сделать индексом

# %%
# Выведем названия колонок во всех дф
for df_name, df in df_dict.items():
    print('-' * 60, df_name)
    for col in sorted(df.columns):
        print(col)
    print()

    del df
# Out:
# ------------------------------------------------------------ market_file
# id
# Акционные_покупки
# Длительность
# Маркет_актив_6_мес
# Маркет_актив_тек_мес
# Неоплаченные_продукты_штук_квартал
# Ошибка_сервиса
# Покупательская активность
# Популярная_категория
# Разрешить сообщать
# Средний_просмотр_категорий_за_визит
# Страниц_за_визит
# Тип сервиса
#
# ------------------------------------------------------------ market_money
# id
# Выручка
# Период
#
# ------------------------------------------------------------ market_time
# id
# Период
# минут
#
# ------------------------------------------------------------ money
# id
# Прибыль

# %%
# Заменим название 'минут' на 'Время на сайте'
market_time.columns = ['id', 'Период', 'Время_на_сайте']

list(market_time.columns)
# Out:
# ['id', 'Период', 'Время_на_сайте']

# %%
# Заменим пробелы на ниж. подчеркивание
market_file.columns = market_file.columns.str.replace(' ', '_')
        
list(market_file.columns)
# Out:
# ['id',
#  'Покупательская_активность',
#  'Тип_сервиса',
#  'Разрешить_сообщать',
#  'Маркет_актив_6_мес',
#  'Маркет_актив_тек_мес',
#  'Длительность',
#  'Акционные_покупки',
#  'Популярная_категория',
#  'Средний_просмотр_категорий_за_визит',
#  'Неоплаченные_продукты_штук_квартал',
#  'Ошибка_сервиса',
#  'Страниц_за_визит']

# %%
# Исправляем орф. ошибки
print('До:')
print(list(market_file['Тип_сервиса'].unique()))
print(list(sorted(market_file['Популярная_категория'].unique())))
print(list(market_time['Период'].unique()), end='\n\n')

market_file['Тип_сервиса'] = market_file['Тип_сервиса'].replace('стандартт', 'стандарт')
market_file['Популярная_категория'] = market_file['Популярная_категория'].replace('Косметика и аксесуары', 'Косметика и аксесcуары')
market_time['Период'] = market_time['Период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

print('После:')
print(list(market_file['Тип_сервиса'].unique()))
print(list(sorted(market_file['Популярная_категория'].unique())))
print(list(market_time['Период'].unique()))
# Out:
# До:
# ['премиум', 'стандартт', 'стандарт']
# ['Домашний текстиль', 'Косметика и аксесуары', 'Кухонная посуда', 'Мелкая бытовая техника и электроника', 'Техника для красоты и здоровья', 'Товары для детей']
# ['текущий_месяц', 'предыдцщий_месяц']
#
# После:
# ['премиум', 'стандарт']
# ['Домашний текстиль', 'Косметика и аксесcуары', 'Кухонная посуда', 'Мелкая бытовая техника и электроника', 'Техника для красоты и здоровья', 'Товары для детей']
# ['текущий_месяц', 'предыдущий_месяц']

# %%
# Проверим на пропуски и дубли
for df_name, df in df_dict.items():
    print(f'{(12-len(df_name)) * ' '}{df_name}: пропусков = {df.isna().sum().sum()}, дублей = {df.duplicated().sum().sum()}', end='\n')
    
    del df, df_name
# Out:
#  market_file: пропусков = 0, дублей = 0
# market_money: пропусков = 0, дублей = 0
#  market_time: пропусков = 0, дублей = 0
#        money: пропусков = 0, дублей = 0

# %%
# Заменим индексы на колонку id
for df_name, df in df_dict.items():
    try:
        print(f'{df_name}:')
        df.set_index('id', inplace=True)
        df = df.sort_values(by=df.columns).sort_index()
    except:
        pass
    
    print(list(df.index[:4]), end='\n\n')
# Out:
# market_file:
# [215348, 215349, 215350, 215351]
#
# market_money:
# [215348, 215348, 215348, 215349]
#
# market_time:
# [215348, 215348, 215349, 215349]
#
# money:
# [215348, 215349, 215350, 215351]

# %% [markdown]
# ### Промежуточный вывод: Предобработка данных
# - Все намеченные исправления выполнены
# - Дублей и пропусков не обнаружено

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных
# Проведем исследовательский анализ данных из каждой таблицы.
# Отберем клиентов с покупательской активностью не менее трех месяцев, т.е. таких, которые что-либо покупали в этот период.

# %%
# Отбор клиентов, по которым была выручка
market_money_not_zero = market_money.query('Выручка > 0')

# Отбор клиентов с покупательской активностью не менее 3-х месяцев
active_clients = market_money_not_zero[market_money_not_zero.groupby('id')['Период'].transform('count') >= 3]

active_clients = active_clients.index.unique().to_list()

# Список id клиентов с покупательской активностью не менее 3-х месяцев
print(f'{len(active_clients)} клиента из {market_money.index.nunique()} имеют покупательскую активность не менее 3-х месяцев.')
# Out:
# 1297 клиента из 1300 имеют покупательскую активность не менее 3-х месяцев.

# %%
for df_name, df in df_dict.items():
    # фильтруем по индексам активных клиентов
    df = df[df.index.isin(active_clients)]
    
    if len(df.select_dtypes(include='number').columns) > 0:
        print('-' * 100, df_name, end='\n\n')

        print('-' * 60, 'df.describe(include="number")', end='\n\n')
        print(df.describe(include='number'), end='\n\n')

    if len(df.select_dtypes(exclude='number').columns) > 0:
        print('-' * 60, 'df.describe(exclude="number")', end='\n\n')
        print(df.select_dtypes(exclude='number').describe(), end='\n\n')
    
    for col_name, col in df.select_dtypes(include='number').items():
        col.hist(bins=50, figsize=(7,5), grid=False)
        plt.title(f'Датафрейм {df_name}')
        plt.xlabel(col_name)
        plt.ylabel('Частота')
        plt.show()
         
    del df, df_name
# Out:
# ---------------------------------------------------------------------------------------------------- market_file
#
# ------------------------------------------------------------ df.describe(include="number")
#
#        Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  Средний_просмотр_категорий_за_визит  Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит
# count             1297.00               1297.00       1297.00            1297.00                              1297.00                             1297.00         1297.00           1297.00
# mean                 4.25                  4.01        602.99               0.32                                 3.27                                2.84            4.18              8.19
# std                  1.02                  0.70        249.10               0.25                                 1.35                                1.97            1.95              3.98
# ...

# %% [markdown]
# На гистограмме выручки в датафрейме `market_money` мы видим, что максимум это единичный вылет.
# Посмотрим сколько таких случаев и исключим их из графика:

# %%
# Посмотрим сколько случаев, где выручка больше 20 тысяч
market_money[market_money.index.isin(active_clients)].query('Выручка > 20000')
# Out:
#                Период   Выручка
# id
# 215380  текущий_месяц 106862.20

# %%
# Исключим эту строчку из исходных данных
market_money = market_money.query('Выручка <= 20000')

# Исключим этот вылет из графика
for col_name, col in market_money[market_money.index.isin(active_clients)].select_dtypes(include='number').items():
        col.hist(bins=50, figsize=(7,5), grid=False)
        plt.title(f'Датафрейм market_money')
        plt.xlabel(col_name)
        plt.ylabel('Частота')
        plt.show()

# %% [markdown]
# ### Промежуточный вывод: Исследовательский анализ данных
# Исходя из графиков гистограмм можно сказать, что метрики:
# `Ошибка_сервиса`, `Cтраниц_за_визит`, `Время_на_сайте`, `Прибыль` имеют нормальное распределение.
# `Выручка` в целом тоже, но график искажен. Остальные метрики распределены не нормально.

# %% [markdown]
# ## Шаг 4. Объединение таблиц
# 1. Объединим датафреймы:
# - `market_file`,
# - `market_money`,
# - `market_time`.
#
#     Данные о прибыли из датафрейма `money` при моделировании нам не понадобятся.
#
# 2. Необходимо учесть, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов.
# В итоговой таблице сделаем отдельный столбец для каждого периода.

# %%
market_money.columns
# Out:
# Index(['Период', 'Выручка'], dtype='object')

# %%
# Транспонируем столбец 'Период'
market_money_pivot = market_money.reset_index().pivot(index='id', columns='Период', values='Выручка'). \
                                                rename(columns={'текущий_месяц': 'Выручка_1', 'предыдущий_месяц': 'Выручка_2', 'препредыдущий_месяц': 'Выручка_3'})
market_time_pivot = market_time.reset_index().pivot(index='id', columns='Период', values='Время_на_сайте'). \
                                                rename(columns={'текущий_месяц': 'Время_на_сайте_1', 'предыдущий_месяц': 'Время_на_сайте_2'})

# Проверка
display(market_money_pivot.head())
display(market_time_pivot.head())
# Out:
# Период  Выручка_2  Выручка_3  Выручка_1
# id
# 215348       0.00       0.00    3293.10
# 215349    5216.00    4472.00    4971.60
# 215350    5457.50    4826.00    5058.40
# 215351    6158.00    4793.00    6610.40
# 215352    5807.50    4594.00    5872.50
# Период  Время_на_сайте_2  Время_на_сайте_1
# id
# 215348                13                14
# 215349                12                10
# 215350                 8                13
# 215351                11                13
# 215352                 8                11

# %% [markdown]
# Заменим названия столбцов на более компактные:
# - текущий месяц = 1
# - предыдущий = 2
# - препредыдущий = 3

# %%
# Отсортируем столбцы
market_money_pivot = market_money_pivot[sorted(market_money_pivot.columns)]
market_time_pivot = market_time_pivot[sorted(market_time_pivot.columns)]

# Проверка
display(market_money_pivot.head())
display(market_time_pivot.head())
# Out:
# Период  Выручка_1  Выручка_2  Выручка_3
# id
# 215348    3293.10       0.00       0.00
# 215349    4971.60    5216.00    4472.00
# 215350    5058.40    5457.50    4826.00
# 215351    6610.40    6158.00    4793.00
# 215352    5872.50    5807.50    4594.00
# Период  Время_на_сайте_1  Время_на_сайте_2
# id
# 215348                14                13
# 215349                10                12
# 215350                13                 8
# 215351                13                11
# 215352                11                 8

# %%
# Форма до объединения
print('Форма до объединения:')
print(market_file.shape, end='\n\n')

# Объединим таблицы
market_df = market_file.join(market_money_pivot).join(market_time_pivot)

# И сделаем аналог для активных клиентов
market_df_active_clients = market_df[market_df.index.isin(active_clients)]

# Проверка
print('Форма после объединения:')
print(market_df.shape, end='\n\n')

# Проверка на NaN
print(f'Проверка на пропуски:')
display(market_df[market_df.isna().any(axis=1)])
# Out:
# Форма до объединения:
# (1300, 12)
#
# Форма после объединения:
# (1300, 17)
#
# Проверка на пропуски:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки            Популярная_категория  Средний_просмотр_категорий_за_визит  Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит  Выручка_1  Выручка_2  Выручка_3  Время_на_сайте_1  Время_на_сайте_2
# id
# 215380                 Снизилась     премиум                нет                1.70                     4           637               0.94  Техника для красоты и здоровья                                    3                                   2               4                 7        NaN    6077.00    5051.00                14                12

# %% [markdown]
# Пропуск есть только в одной строке, это из-за того, что не было покупок в этом месяце у этого клиента.
# Чтобы заполнить этот пропуск предположим, что он будет тратить столько же в этом месяце, сколько и в прошлом.

# %%
market_df.loc[market_df.index == 215380, 'Выручка_1'] = market_df.loc[market_df.index == 215380, 'Выручка_2']

# Проверка
market_df[market_df.index == 215380][['Выручка_1', 'Выручка_2', 'Выручка_3']]
# Out:
#         Выручка_1  Выручка_2  Выручка_3
# id
# 215380    6077.00    6077.00    5051.00

# %%
# Обновим дф активных клиентов
market_df_active_clients = market_df[market_df.index.isin(active_clients)]

# %% [markdown]
# ### Промежуточный вывод: Объединение таблиц
# - разложили два столбца с периодами на 5 разных столбцов
# - успешно объединили таблицы

# %% [markdown]
# ## Шаг 5. Корреляционный анализ
# Проведем корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования.

# %%
# Сперва необходимо закодировать строковые колонки
label_encoder = LabelEncoder()

cat_mdfac = market_df_active_clients.select_dtypes(exclude='number')

# Список для хранения преобразованных данных
cat_data = []

# Список для хранения имен столбцов
cat_name = cat_mdfac.columns.tolist()

# Преобразуем каждый категориальный столбец
for col in cat_mdfac:
    # Применяем LabelEncoder к каждому столбцу
    temp = label_encoder.fit_transform(cat_mdfac[col])
    cat_data.append(temp)

# Создаем новый датафрейм с закодированными данными
cat_df = pd.DataFrame(cat_data).T  # транспонируем, чтобы строки стали столбцами
cat_df.columns = cat_name  # устанавливаем имена столбцов

# Сохраняем индекс оригинального датафрейма
cat_df.index = cat_mdfac.index

display(cat_mdfac.head(10))
display(cat_df.head(10))
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать    Популярная_категория
# id
# 215349                 Снизилась     премиум                 да        Товары для детей
# 215350                 Снизилась    стандарт                нет       Домашний текстиль
# 215351                 Снизилась    стандарт                 да        Товары для детей
# 215352                 Снизилась    стандарт                нет        Товары для детей
# 215353                 Снизилась    стандарт                 да       Домашний текстиль
# 215354                 Снизилась    стандарт                 да  Косметика и аксесcуары
# 215355                 Снизилась    стандарт                нет        Товары для детей
# 215356                 Снизилась    стандарт                 да  Косметика и аксесcуары
# 215358                 Снизилась    стандарт                 да       Домашний текстиль
# 215360                 Снизилась     премиум                 да         Кухонная посуда
# ...

# %%
# сделаем дф для анализа корреляции, чтобы строковые значения были числовыми
df_for_corr = market_df_active_clients.select_dtypes(include='number').join(cat_df)

# Построим корреляционную матрицу для активных клиентов
phik_overview = df_for_corr.phik_matrix(interval_cols=df_for_corr.columns)

# визуализация тепловой карты коэффициентов корреляции
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    title=r"correlation $\phi_K$",
    figsize=(12, 8))

# %% [markdown]
# ### Промежуточный вывод: Корреляционный анализ
# Мультиколлинеарность не обнаружена

# %% [markdown]
# ## Шаг 6. Использование пайплайнов
# Применим все изученные модели. Для этого используем пайплайны.
#
# 1. Во время подготовки данных используем `ColumnTransformer`.
#     - Количественные и категориальные признаки обработаем в пайплайне раздельно,
#     - Для кодирования категориальных признаков используем как минимум два кодировщика,
#     - для масштабирования количественных — как минимум два скейлера.
#
# Для каждой модели подготовим данные с разным кодированием и масштабированием.
#
# 2. Обучим четыре модели:
# - `KNeighborsClassifier()`,
# - `DecisionTreeClassifier()`,
# - `LogisticRegression()`,
# - `SVC()`.
#
# Для каждой из них подберем как минимум один гиперпараметр.
# Выберем подходящую для задачи метрику, аргументируем свой выбор.
# Используем эту метрику при подборе гиперпараметров.
#
# 3. Выберем лучшую модель, используя заданную метрику. Для этого применим одну из стратегий:
# - использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
# - использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернет лучшую модель.

# %% [markdown]
# Для оценки качества присвоения классов модели используем ROC-AUC.
#
# Т.к. с помощью неё можно проверить точность модели, невзирая на дисбаланс классов (на который мы не проверяли данные),
# и на выбранный порог (который мы тоже вручную не задавали). Остальные метрики узконаправлены и зависят от описанных выше случаев.

# %%
# Делаем бэкап
df_pipe = market_df_active_clients.copy()

# Определим количественные и категориальные признаки
num_columns = df_pipe.select_dtypes(include='number').columns
# Выберем все бинарные признаки (кроме целевого)
ord_columns = ['Тип_сервиса','Разрешить_сообщать']
# Остальные нечисловые признаки
ohe_columns = df_pipe.select_dtypes(exclude='number').drop(['Покупательская_активность'] + ord_columns, axis=1).columns

# Делаем сплит данных
X_train, X_test, y_train, y_test = train_test_split(
    df_pipe.drop(['Покупательская_активность'], axis=1),
    df_pipe['Покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = df_pipe['Покупательская_активность'])

# обучаем модель и трансформируем тренировочную выборку 
y_train = label_encoder.fit_transform(y_train) # Прежний уровень = 0, Снизилась = 1

# трансформируем тестовую выборку
y_test = label_encoder.transform(y_test) # Прежний уровень = 0, Снизилась = 1

# Создаем пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                 categories=[
                    ['стандарт', 'премиум'], 
                    ['нет', 'да']
                 ],
                 handle_unknown='use_encoded_value', 
                 unknown_value=np.nan)),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ])
              
# Создаем пайплайн для подготовки категориальных признаков: заполним пропуски и применим OHE
try:
    ohe_pipe = Pipeline([
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')), 
        ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse=False))
    ])
except:
    ohe_pipe = Pipeline([
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')), 
        ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse_output=False))
    ])

# Создаем пайплайн для количественных признаков: применим разные скейлеры
num_pipe = Pipeline([
    ('simpleImputer_num', SimpleImputer(missing_values=np.nan, strategy='mean')), 
    ('scaler', MinMaxScaler())
])

# Создаем общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough')

# Пайплайн для каждой модели: подготовка данных + модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# Словари для гиперпараметров для разных моделей
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели KNeighborsClassifier() 
    {
        # название модели
        'models': [KNeighborsClassifier()],
        # указываем гиперпараметр модели n_neighbors
        'models__n_neighbors': range(2, 5),
        # указываем список методов масштабирования
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(solver='liblinear', penalty='l1', random_state=RANDOM_STATE)],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели SVC()
    {
        'models': [SVC(probability=True, random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }] 

# Настроим RandomizedSearchCV для подбора гиперпараметров
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# Обучаем модель
randomized_search.fit(X_train, y_train)

# Выводим лучшую модель и ее параметры
print('Лучшая модель и ее параметры:\n\n', randomized_search.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', round(randomized_search.best_score_, 3))

# Проверим работу модели на тестовой выборке
proba = randomized_search.predict_proba(X_test)

# Вероятность прежнего уровня
proba_one = proba[:, 1]

# Вероятность снижения
proba_zero = proba[:, 0]

print('Площадь ROC-кривой:', round(roc_auc_score(y_test, proba_one), 3))
# Out:
# Лучшая модель и ее параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   Index(['Популярная_категория'], dtype='object')),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %% [markdown]
# ### Промежуточный вывод: Использование пайплайнов

# %% [markdown]
# ## Шаг 7. Анализ важности признаков
#
# 1. Оценим важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.
# 2. Сделаем выводы о значимости признаков:
#     - какие признаки мало значимы для модели;
#     - какие признаки сильнее всего влияют на целевой признак;
#     - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %%
# Достаем имена признаков
all_feature_names = randomized_search.best_estimator_['preprocessor'].get_feature_names_out()

# Убираем приставки названий шагов
all_feature_names = [name.split('__')[-1] for name in all_feature_names]

# Преобразуем данные и создаем датафрейм с нужными именами признаков
X_transformed = randomized_search.best_estimator_['preprocessor'].transform(X_train)

# Преобразуем результат в датафрейм с нужными именами признаков
X_transformed_df = pd.DataFrame(X_transformed, columns=all_feature_names)

# Для удобства
model = randomized_search.best_estimator_['models']

# Создаем объяснитель для SHAP
explainer = shap.Explainer(model.predict, X_transformed_df.values) # добавляем .values, чтобы передать массив, как было при обучении

# Закрепляем порядок значений в SHAP, используя фиксированный набор данных
shap_values = explainer(X_transformed_df[:10])

# Визуализируем SHAP-значения
shap.plots.beeswarm(shap_values, max_display=20)
shap.plots.bar(shap_values, max_display=20)

# %%
# На первом графике вручную выберем значения принадлежности к классу
# Прежний уровень
class_zero = ['Страниц_за_визит','Средний_просмотр_категорий_за_визит','Время_на_сайте_1','Время_на_сайте_2','Маркет_актив_6_мес','Выручка_3','Выручка_1','Популярная_категория']

# Снизилась
class_one = ['Неоплаченные_продукты_штук_квартал','Акционные_покупки','Выручка_2','Длительность']

# Преобразуем SHAP-значения в датафрейм
shap_df = pd.DataFrame(shap_values.values, columns=X_transformed_df.columns)

# Печатаем DataFrame с SHAP-значениями
display(abs(shap_df).sum().sort_values(ascending=False))

# Сделаем список признаков под удаление
features_drop = abs(shap_df).sum().sort_values(ascending=False)

features_drop[features_drop < 0.09].index.to_list()
# Out:
# Страниц_за_визит                                            0.95
# Неоплаченные_продукты_штук_квартал                          0.81
# Время_на_сайте_2                                            0.56
# Средний_просмотр_категорий_за_визит                         0.53
# Время_на_сайте_1                                            0.52
# Акционные_покупки                                           0.51
# Маркет_актив_6_мес                                          0.46
# Популярная_категория_Мелкая бытовая техника и электроника   0.33
# Выручка_3                                                   0.25
# Выручка_2                                                   0.20
# Длительность                                                0.14
# Популярная_категория_Техника для красоты и здоровья         0.12
# Выручка_1                                                   0.10
# Ошибка_сервиса                                              0.05
# ...

# %%
# Взглянем на соотношение клиентов с подпиской и без неё
print(f"Доля клиентов с подпиской = {round(df_pipe['Тип_сервиса'].value_counts()[1]/df_pipe['Тип_сервиса'].value_counts().sum() * 100)}%")
df_pipe['Тип_сервиса'].value_counts()
# Out:
# Доля клиентов с подпиской = 29%
# Тип_сервиса
# стандарт    922
# премиум     375
# Name: count, dtype: int64

# %% [markdown]
# ### Промежуточный вывод: Анализ важности признаков
# Сильнее всего на целевой признак влияют следующие признаки:
# - `Страниц_за_визит`,
# - `Неоплаченные_продукты_штук_квартал`,
# - `Время_на_сайте_2`,
# - `Средний_просмотр_категорий_за_визит`,
# - `Время_на_сайте_1`,
# - `Акционные_покупки`,
# - `Маркет_актив_6_мес`.
#
# На вероятность присвоения 0 класса ("Прежний уровень") сильнее всего влияют признаки:
# - `Страниц_за_визит`,
# - `Средний_просмотр_категорий_за_визит`,
# - `Время_на_сайте_2`,
# - `Время_на_сайте_1`,
# - `Маркет_актив_6_мес`,
# - `Выручка_3`,
# - `Выручка_1`,
# - `Популярная_категория`.
#
# На вероятность присвоения 1 класса ("Снизилась") сильнее всего влияют признаки:
# - `Неоплаченные_продукты_штук_квартал`,
# - `Акционные_покупки`,
# - `Выручка_2`,
# - `Длительность`.
#
# Малозначимы для модели признаки, у которых влияние менее 0.1 это:
# - `Ошибка_сервиса`,
# - `Популярная_категория_Товары для детей`,
# - `Популярная_категория_Мелкая бытовая техника и электроника`,
# - `Маркет_актив_тек_мес`,
# - `Тип_сервиса`,
# - `Разрешить_сообщать` и др.
#
# Для увеличения точности можно их удалить.
#
# Исходя из полученных данных, на графике, мы хорошо видим совершенно логичные вещи:
# - Чем больше клиент просмотрел страниц, категорий и провел времени на сайте тем выше вероятность, что его активность останется прежней,
# - Наличие неоплаченных товаров хорошо указывает на клиентов, активность которых снижается/снизилась.
#
# Я бы порекомендовал проработать:
# 1. Маркетинговые решения.
# Видно, что реклама работает вдолгую, возможно кампания не использует выгодные ежемесячные акции, либо возможно данные нам дали те, в которых текущий месяц был не сезонный.
# Как минимум можно потестить увеличение % скидки, если ежемесячные акции все-таки есть или рассмотреть кейс с вовлечением аудитории на розыгрыш и т.п.;
# 2. Добавить пуши/письма клиентам, которые не оплатили вещи из корзины
# Часть из них наверняка просто забыла их оплатить (у меня такое бывает);
# 3. Насколько я могу судить по обороту выручки, магазин достаточно нишовый,
# имеет смысл уделить внимание категории электроники и товаров для детей, если есть желание их развивать, т.к. сейчас они не пользуется спросом;
# 4. Судя по тому, что тип сервиса никак не влияет на присвоение класса, могу предположить, что бонусы премиум подписки не очень выгодные.
# Это подтверждает довольно маленький % клиентов с подпиской, их наберется едва треть пользователей;
# 5. Судя по тому, что ошибки сервиса никак не влияют на вероятность присвоения класса, можно сказать, что их либо очень мало, либо они оперативно чинятся.
# В любом случае можно поставить лайк команде сопровождения сервиса!

# %% [markdown]
# ## Шаг 8. Сегментация покупателей
#
# 1. Выполним сегментацию покупателей.
# Используем результаты моделирования и данные о прибыльности покупателей.
# 2. Выберем группу покупателей и предложим, как увеличить ее покупательскую активность:
# - Проведем графическое и аналитическое исследование группы покупателей.
# - Сделаем предложения по работе с сегментом для увеличения покупательской активности.
#
# 3. Сделаем выводы о сегментах:
# - какой сегмент мы взяли для дополнительного исследования,
# - какие предложения мы сделали и почему.

# %%
# Добавим вероятность снижения активности и прибыль к тестовой выборке
result = pd.DataFrame(proba_zero, columns=['Вероятность_снижения'], index=X_test.index).join(X_test).join(money)

display(result.head())

print('Количество пропусков после добавления прибыли =', result[result['Прибыль'].isna()].count().sum())
# Out:
#         Вероятность_снижения Тип_сервиса Разрешить_сообщать  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки            Популярная_категория  Средний_просмотр_категорий_за_визит  Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит  Выручка_1  Выручка_2  Выручка_3  Время_на_сайте_1  Время_на_сайте_2  Прибыль
# id
# 216446                  0.55    стандарт                 да                5.30                     5           433               0.91  Техника для красоты и здоровья                                    1                                   1               0                 7    5230.70    4712.00    5160.00                20                15     4.47
# ...

# %%
# Построим график рассеяния вероятности снижения и прибыли
plt.figure(figsize=(12,6))
sns.scatterplot(data=result, x='Вероятность_снижения', y='Прибыль', color='purple')
plt.show()

# %%
# Исходя из графика выше, выберем прибыльных клиентов, вероятность снижения которых больше 0.5
result_chosen = result.query('Вероятность_снижения > 0.59 and Прибыль > 3.65')

plt.figure(figsize=(12,6))
sns.scatterplot(data=result, x='Вероятность_снижения', y='Прибыль', label='Другие сегменты', color='purple')
sns.scatterplot(data=result_chosen, x='Вероятность_снижения', y='Прибыль', label='Исследуемый сегмент', color='blue') # тут оказывается важен порядок, хз почему в примере не так

plt.legend()
plt.axvline(x=0.59, color='g', ls='--')
plt.axhline(y=3.65, color='g', ls='--')
plt.show()

# %% [markdown]
# Попробуем понять, почему активность клиентов исследуемого сегмента начнет снижаться:

# %%
# Посмотрим клиенты каких категорий чаще всего покидают ряды постоянных клиентов
print('Распределение популярности категорий внутри исследуемого сегмента:', end='\n\n')
print(result_chosen['Популярная_категория'].value_counts(), end='\n\n')

# И какая часть клиентов этого сегмента пользуется премиум сервисом
print(f"Доля премиум клиентов — {round(result_chosen['Тип_сервиса'].value_counts()[1]/result_chosen['Тип_сервиса'].value_counts().sum() * 100)}%", end='\n\n')

# Есть разрешение на коммуникацию?
print(f"Получают коммуникацию — {round(result_chosen['Разрешить_сообщать'].value_counts()[0]/result_chosen['Разрешить_сообщать'].value_counts().sum() * 100)}%", end='\n\n')

# Насколько часто происходили коммуникации?
print('Количество маркетинговых коммуникаций в текущем месяце —', result_chosen['Маркет_актив_тек_мес'].sum(), end='\n\n')
print('Коммуникаций в среднем в месяц за посл. 6 мес. —', round(result_chosen['Маркет_актив_6_мес'].sum()), end='\n\n')

# Как часто покупали по акции?
print(f"Доля купленных товаров по акции — {round(result_chosen['Акционные_покупки'].sum()/result_chosen['Акционные_покупки'].count() * 100)}%")
# Out:
# Распределение популярности категорий внутри исследуемого сегмента:
#
# Популярная_категория
# Товары для детей                        28
# Домашний текстиль                       25
# Мелкая бытовая техника и электроника    24
# Косметика и аксесcуары                  22
# Техника для красоты и здоровья          17
# Кухонная посуда                         13
# Name: count, dtype: int64
#
# Доля премиум клиентов — 27%
#
# Получают коммуникацию — 76%
#
# Количество маркетинговых коммуникаций в текущем месяце — 506
#
# Коммуникаций в среднем в месяц за посл. 6 мес. — 588
#
# Доля купленных товаров по акции — 21%

# %% [markdown]
# ### Промежуточный вывод: Сегментация покупателей
# - Можно предположить, что клиентами этой категории являются в основном женщины, от 23 до 45 лет, навскидку.
# Т.к. большая часть товаров связана со здоровьем/красотой, детьми и обустройством дома (кухни).
#
#
# - Доля премиум подписок немногим выше основной массы клиентов, а значит подписка +- одинаково выгодна/не выгодна всем.
#
#
# - Похоже товары для детей пользуются наибольшим спросом, возможно стоит понять насколько приоритетна сейчас эта категория в кампании.
# Во многом это зависит от того, будет расширяться ассортимент конкретной категории (например, узкоспециализированные интернет-магазины как "всеинструменты.ру")
# или ассортимент за счет добавления новых категорий и позиций к ним (озон, вб и прочее).
#
#
# - Стоит проанализировать какие маркетинговые предложения были в последнем месяце, т.к. кол-во купленных акционных товаров всего 21% (акции или не работают, или их нет).
#
#
# - Стоит подумать о том, что нужно клиентам и что нужно кампании, чтобы сделать взаимовыгодный вариант подписки, вместо текущего премиума (т.к. доля премиум клиентов в исследуемом сегменте всего 27%).

# %% [markdown]
# ## Шаг 9. Общий вывод
#
# ### Сделаем общий вывод:
# - Нам было необходимо разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
# - В ходе предобработки:
#     - Привели подписи столбцов к одному формату
#     - Исправили орфографические ошибки
#     - Проверили данные на пропуски и дубли (их не оказалось)
#     - Столбец с ID сделали индексом
# - Для поиска лучшей модели мы использование пайплайны (для ускорения подбора модели и параметров)
# Используя метрику ROC-AUC выбрали лучшую модель и гиперпараметры для неё.
# Лучшей моделью стала логистическая регрессия
#
# Рекомендации на основе исследования:
# 1. Проанализировать какие маркетинговые предложения были в последнем месяце.
# Возможно было много экспериментов (например, вышел новый сотрудник) или наоборот уже полгода одни и те же письма, от которых нет результата.
# 2. Добавить "фичу": пуши/письма клиентам, которые не оплатили вещи из корзины.
# Те, кто забыли и те, кто сомневались, оплатят товар.
# 3. Оценить емкость рынка.
# Вполне возможно, что рынок текущей потребности полностью закрыт и/или исчерпался в локациях присутствия ПВЗ и партнеров.
# 4. Платная подписка.
# Подумать нужна ли она, если не пользуется спросом. Можно собрать фокус-группу из покупателей и "побрейнштормить".
# 5. Выбрать путь развития кампании:
#     - узкий рынок конкретных 4-5 категорий
#     - расширение категорий (добавление смежных текущим)
